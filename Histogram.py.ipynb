# %% [markdown]
# ### Histogram

# %% [markdown]
#     Histogram are the most common means of looking at a single variable.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure(figsize = (10,8))
axes1 = fig.add_subplot(1,1,1)
axes1.hist(df[['total_bill', 'tip']], color = ["gold", 'black'], orientation = "vertical")
axes1.set_title("Histogram of Total bills")
axes1.set_xlabel("Frequency")
axes1.set_ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
#     In the above program we find that histogram of total bill and tip values

# %%
fig = plt.figure(figsize = (10,8))
axes1 = fig.add_subplot(1,1,1)
axes1.hist(df[['sex', 'smoker']], color = ["pink", 'green'], orientation = "vertical")
axes1.set_title("Histogram of sex")
axes1.set_xlabel("Frequency")
axes1.set_ylabel("smoker")
# Out:
# Text(0, 0.5, 'smoker')

# %% [markdown]
#     In the above program we find that  histogram of gender values, about smoking male gender has highest smoking habit

# %%
fig = plt.figure(figsize = (10,8))
axes1 = fig.add_subplot(1,1,1)
axes1.hist(df[['time', 'day']], color = ["red", 'gold'], orientation = "vertical")
axes1.set_title("Histogram of Day")
axes1.set_xlabel("Frequency")
axes1.set_ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
#     In the above program find that according to time and day,in that time and day dinner is the most vising time and day is the saturday

# %%
plt.figure(figsize = (2,2))
sns.countplot("day", data = df)
# Out:
# C:\Users\SRAM2\AppData\Local\Programs\Python\Python39-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
#     In the above program find that at the saturday is the highest visiting day

# %%
fig = plt.figure(figsize = (10,8))
axes1 = fig.add_subplot(1,1,1)
axes1.hist(df[['time', 'size']], color = ["red", 'gold'], orientation = "vertical")
axes1.set_title("Histogram of Time")
axes1.set_xlabel("size")
axes1.set_ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
#     In the above code in the tips data lunch and dinner is the most visit timings

# %%
df = sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_1 = df[df['dataset'] == 'I']

# %%
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
dataset_2 = df[df['dataset'] == 'II']

# %%
dataset_2
# Out:
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74

# %%
dataset_3 = df[df['dataset'] == 'III']

# %%
dataset_3
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
dataset_4 = df[df['dataset'] == 'IV']

# %%
dataset_4
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10,8))
axes1 = fig.add_subplot(1,1,1)
axes1.hist(df['dataset'], color = ["gold"], orientation = "vertical")
axes1.set_title("Histogram of Dataset")
axes1.set_xlabel("Frequency")
axes1.set_ylabel("dataset")
# Out:
# Text(0, 0.5, 'dataset')

# %% [markdown]
#     In the above program find that histogram of dataset
